# %%
import os
import sys
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv('data/train_prepared_basic.csv')
test_data = pd.read_csv('data/test_prepared_basic.csv')
train_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                   Id  Week        V1        V2  \
# 0           0             0 -6536978109522202983     0 -1.214669 -1.229582
# 1           1             1 -6536978109522202983     1 -1.214669 -1.229582
# 2           2             2 -6536978109522202983     2 -1.214669 -1.229582
# 3           3             3 -6536978109522202983     3 -1.214669 -1.229582
# 4           4             4 -1744017237843019509     0  0.261222  0.150750
#
#          V3        V4        V9       V11  ...       V19       V20       V22  \
# 0 -1.304097 -0.384279  1.618840  1.689373  ... -0.610111 -1.627840 -0.607143
# 1 -1.304097 -0.384279  1.618840  1.689373  ... -0.610111 -1.627840 -0.607143
# 2 -1.304097 -0.384279  1.618840  1.689373  ... -0.610111 -1.627840 -0.607143
# 3 -1.304097 -0.384279  1.618840  1.689373  ... -0.610111 -1.627840 -0.607143
# 4 -0.159125 -0.067517  2.039992 -0.419042  ... -0.610111 -0.837594 -0.607143
#
#          P8        P9       P10       P11       P12       P23  target
# 0 -0.488522 -0.364388  0.614911 -1.841831 -1.681824 -0.402846     0.0
# 1 -0.488522 -0.364388  0.233876 -0.237328 -1.681824 -0.402846     0.0
# 2 -0.488522 -0.364388  0.760227  0.614045 -1.681824 -0.402846     0.0
# 3  1.025732  2.235298 -0.062077 -0.499621 -1.878605  2.481332     0.0
# 4 -0.488522 -0.364388  0.468424 -0.025675 -1.381967  2.365924     0.0
#
# [5 rows x 54 columns]

# %%
train_data = train_data.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
test_data = test_data.drop(['Unnamed: 0'], axis=1)

# %%
def id_group_transform(data):
    # res = data.groupby(["Id"]).nth(0)
    res1 = data[data["Week"] == 0].copy()
    res1.drop(columns=(column_name for column_name in data.columns if column_name.startswith("P")), inplace=True)

    new_p_tables = []
    for week in range(4):
        temp = data[data["Week"] == week].copy()
        temp.drop(columns=(column_name for column_name in data.columns if not column_name.startswith("P") and column_name != "Id"), inplace=True)
        temp.rename(lambda name: name+f"_W{week}" if name.startswith("P") else name, axis="columns", inplace=True)
        new_p_tables.append(temp)


    res = res1.merge(new_p_tables[0], how="inner", on="Id")
    res = res.merge(new_p_tables[1], how="inner", on="Id")
    res = res.merge(new_p_tables[2], how="inner", on="Id")
    res = res.merge(new_p_tables[3], how="inner", on="Id")
    return res

# %%
X_train = id_group_transform(train_data)
X_test = id_group_transform(test_data)
y_train = X_train['target']
X_train = X_train.drop(['target', 'Week'], axis=1)
X_test = X_test.drop(['Week'], axis=1)
X_train.head()
# Out:
#                     Id        V1        V2        V3        V4        V9  \
# 0 -6536978109522202983 -1.214669 -1.229582 -1.304097 -0.384279  1.618840
# 1 -1744017237843019509  0.261222  0.150750 -0.159125 -0.067517  2.039992
# 2 -9187108666132882725  1.466966  1.713691 -1.304097 -0.946387  0.885337
# 3 -1259418257712246678  0.732093  0.632798 -0.678160  0.855476  0.436725
# 4  7132677487852039192 -1.214669 -1.229582 -1.304097 -1.354000  0.750737
#
#         V11       V14       V15       V16  ...    P24_W3    P25_W3    P26_W3  \
# 0  1.689373  0.844507  0.540733  1.682240  ... -1.830169  0.039483  0.720327
# 1 -0.419042 -1.029798 -1.380197  0.948993  ... -0.962976  0.698748  1.133250
# 2 -0.962336 -0.303839 -0.937923 -0.184209  ...  1.081511  0.977721 -0.220856
# 3  0.082047 -0.021030 -0.679664 -1.148976  ...  1.454927 -1.721148  0.666257
# 4  1.297364 -1.029798 -1.380197  1.976676  ... -0.099432  0.880689 -1.221282
#
#      P27_W3     P8_W3     P9_W3    P10_W3    P11_W3    P12_W3    P23_W3
# 0  0.387509  1.025732  2.235298 -0.062077 -0.499621 -1.878605  2.481332
# 1  1.017659 -0.488522 -0.364388 -0.039009 -0.114774 -0.926357  2.597932
# 2 -0.470120 -0.488522 -0.364388  0.114520 -0.783241  1.141776 -0.402846
# 3  1.265662 -0.488522 -0.364388 -1.021933 -0.063885  1.512694 -0.402846
# 4 -1.965960 -0.488522 -0.364388 -1.257932 -1.513413 -0.014069 -0.402846
#
# [5 rows x 131 columns]

# %%
X_train = X_train.set_index('Id')
X_test = X_test.set_index('Id')

# %%
def generate_deltas(df):
    for i in range(27):
        for week in range(3):
            df[f'P{i+1}_W{week+1}-{week}'] = df[f'P{i+1}_W{week+1}'] - df[f'P{i+1}_W{week}']
        df[f'P{i+1}_W3-0'] = df[f'P{i+1}_W3'] - df[f'P{i+1}_W0']
    return df

# %%
X_train = generate_deltas(X_train)
X_test = generate_deltas(X_test)
X_train.head()
# Out:
#                             V1        V2        V3        V4        V9  \
# Id
# -6536978109522202983 -1.214669 -1.229582 -1.304097 -0.384279  1.618840
# -1744017237843019509  0.261222  0.150750 -0.159125 -0.067517  2.039992
# -9187108666132882725  1.466966  1.713691 -1.304097 -0.946387  0.885337
# -1259418257712246678  0.732093  0.632798 -0.678160  0.855476  0.436725
#  7132677487852039192 -1.214669 -1.229582 -1.304097 -1.354000  0.750737
#
#                            V11       V14       V15       V16       V17  ...  \
# Id                                                                      ...
# -6536978109522202983  1.689373  0.844507  0.540733  1.682240  0.014685  ...
# -1744017237843019509 -0.419042 -1.029798 -1.380197  0.948993  1.250200  ...
# -9187108666132882725 -0.962336 -0.303839 -0.937923 -0.184209 -0.481364  ...
# -1259418257712246678  0.082047 -0.021030 -0.679664 -1.148976  1.673578  ...
#  7132677487852039192  1.297364 -1.029798 -1.380197  1.976676 -1.193582  ...
#
#                       P25_W3-2  P25_W3-0  P26_W1-0  P26_W2-1  P26_W3-2  \
# Id
# -6536978109522202983 -0.139155  0.323217 -0.399568 -1.078469  0.851133
# -1744017237843019509 -0.131692  0.093221  0.635130  0.291939  1.012301
# -9187108666132882725  0.583060  0.019954 -0.276790  0.361082  0.560520
# -1259418257712246678  0.000000  0.000000 -0.153241  0.589407  0.293758
#  7132677487852039192 -0.066926  0.030087  0.310174  0.252770 -0.732799
#
#                       P26_W3-0  P27_W1-0  P27_W2-1  P27_W3-2  P27_W3-0
# Id
# -6536978109522202983 -0.626903  0.202123 -0.837158  0.848628  0.213592
# -1744017237843019509  1.939370  0.565416  0.726801 -0.077080  1.215138
# -9187108666132882725  0.644812 -0.222499  0.425951 -0.212453 -0.009001
# -1259418257712246678  0.729925  0.053212  0.090980  0.200677  0.344869
#  7132677487852039192 -0.169856 -0.307380  0.000000  0.000000 -0.307380
#
# [5 rows x 238 columns]

# %%
def generate_divs(df):
    for i in range(27):
        for week in range(3):
            df[f'P{i+1}_W{week+1}/{week}'] = (df[f'P{i+1}_W{week+1}'] - df[f'P{i+1}_W{week+1}'].min() + 1) / (df[f'P{i+1}_W{week}'] - df[f'P{i+1}_W{week}'].min() + 1)
        df[f'P{i+1}_W3/0'] = (df[f'P{i+1}_W3'] - df[f'P{i+1}_W3'].min() + 1) / (df[f'P{i+1}_W0'] - df[f'P{i+1}_W0'].min() + 1)
    return df

# %%
X_train = generate_divs(X_train)
X_test = generate_divs(X_test)
X_train
# Out:
#                             V1        V2        V3        V4        V9  \
# Id
# -6536978109522202983 -1.214669 -1.229582 -1.304097 -0.384279  1.618840
# -1744017237843019509  0.261222  0.150750 -0.159125 -0.067517  2.039992
# -9187108666132882725  1.466966  1.713691 -1.304097 -0.946387  0.885337
# -1259418257712246678  0.732093  0.632798 -0.678160  0.855476  0.436725
#  7132677487852039192 -1.214669 -1.229582 -1.304097 -1.354000  0.750737
# ...                        ...       ...       ...       ...       ...
#  1725230195494199693  1.484947  0.632798  0.847232  0.784340 -1.137487
# -3951248822562299280 -0.154476  0.150750 -0.639985 -0.800899 -0.610984
#  5107134433121260865 -0.154476  0.150750  1.328129 -0.126426  1.131934
#  2010738301694279951  0.768499  0.632798 -0.639233  1.893963 -0.420111
#  8802977523104348852 -0.022410  0.150750  0.019754  0.146255  0.023278
#
#                            V11       V14       V15       V16       V17  ...  \
# Id                                                                      ...
# -6536978109522202983  1.689373  0.844507  0.540733  1.682240  0.014685  ...
# -1744017237843019509 -0.419042 -1.029798 -1.380197  0.948993  1.250200  ...
# -9187108666132882725 -0.962336 -0.303839 -0.937923 -0.184209 -0.481364  ...
# -1259418257712246678  0.082047 -0.021030 -0.679664 -1.148976  1.673578  ...
#  7132677487852039192  1.297364 -1.029798 -1.380197  1.976676 -1.193582  ...
# ...                        ...       ...       ...       ...       ...  ...
#  1725230195494199693  0.267028 -1.029798  0.212677 -0.551541  0.355025  ...
# -3951248822562299280 -0.135951 -0.019277 -0.064148 -0.196778 -0.277898  ...
#  5107134433121260865  0.566143 -1.029798 -0.240007  0.327260  0.304397  ...
#  2010738301694279951  1.577818  0.237095 -0.277931  1.462554 -1.193582  ...
#  8802977523104348852  0.040626 -0.173024 -0.237815 -0.089396 -0.074093  ...
#
#                       P25_W3/2  P25_W3/0  P26_W1/0  P26_W2/1  P26_W3/2  \
# Id
# -6536978109522202983  0.952012  1.132607  0.923548  0.776568  1.227068
# -1744017237843019509  0.962920  1.028022  1.206677  1.078729  1.253068
# -9187108666132882725  1.187130  1.005424  0.908150  1.131940  1.180942
# -1259418257712246678  1.000000  1.000000  0.959837  1.160941  1.069093
#  7132677487852039192  0.981758  1.008424  1.109690  1.080553  0.783879
# ...                        ...       ...       ...       ...       ...
#  1725230195494199693  1.000000  1.000000  0.943814  1.040430  0.793157
# -3951248822562299280  1.341894  0.998789  1.302065  1.271565  0.744624
#  5107134433121260865  1.062363  1.100758  1.052223  1.104892  1.112482
#  2010738301694279951  0.936976  0.878815  1.242141  0.905193  0.945741
#  8802977523104348852  1.285966  1.989392  1.418366  0.768302  0.814183
#
#                       P26_W3/0  P27_W1/0  P27_W2/1  P27_W3/2  P27_W3/0
# Id
# -6536978109522202983  0.880051  1.064373  0.810207  1.238488  1.068026
# -1744017237843019509  1.631090  1.204233  1.278854  0.934339  1.438919
# -9187108666132882725  1.213974  0.911172  1.275516  0.857334  0.996406
# -1259418257712246678  1.191305  1.013691  1.074582  0.999482  1.088729
#  7132677487852039192  0.939932  0.764889  1.202870  0.831345  0.764889
# ...                        ...       ...       ...       ...       ...
#  1725230195494199693  0.778859  1.043927  0.928384  1.232346  1.194347
# -3951248822562299280  1.232844  0.614939  3.196576  0.511961  1.006362
#  5107134433121260865  1.293364  1.098864  1.029986  1.163398  1.316750
#  2010738301694279951  1.063370  1.347877  1.023204  1.105656  1.524868
#  8802977523104348852  0.887242  1.779847  0.793393  0.766862  1.082900
#
# [7715 rows x 346 columns]

# %%
df_train = X_train.copy()
df_train['target'] = y_train
df_train.reset_index(drop=True, inplace=True)
df_train.to_csv('data/train_prepared_oneliner_w_deltas_n_divs.csv')
X_test.to_csv('data/test_prepared_oneliner_w_deltas_n_divs.csv')
